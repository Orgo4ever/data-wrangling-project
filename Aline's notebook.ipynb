# %%
import pandas as pd
import numpy as np
# %pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\ASUS\Desktop\Ironhack\Projects\week_data-wrangling-project

# %%
# Load the dataset
df = pd.read_excel(
    r"C:\Users\ASUS\Desktop\Ironhack\Projects\week_data-wrangling-project\eurostat_monthly_electricity.xlsx"
)

# Display the first 5 rows
df.head()
# Out:
#   STRUCTURE                      STRUCTURE_ID  \
# 0  dataflow  ESTAT:NRG_CB_EM$DEFAULTVIEW(1.0)
# 1  dataflow  ESTAT:NRG_CB_EM$DEFAULTVIEW(1.0)
# 2  dataflow  ESTAT:NRG_CB_EM$DEFAULTVIEW(1.0)
# 3  dataflow  ESTAT:NRG_CB_EM$DEFAULTVIEW(1.0)
# 4  dataflow  ESTAT:NRG_CB_EM$DEFAULTVIEW(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Supply, transformation and consumption of elec...    M        Monthly
# 1  Supply, transformation and consumption of elec...    M        Monthly
# 2  Supply, transformation and consumption of elec...    M        Monthly
# 3  Supply, transformation and consumption of elec...    M        Monthly
# 4  Supply, transformation and consumption of elec...    M        Monthly
#
#   nrg_bal                Energy balance   siec  \
# 0     AIM  Available to internal market  E7000
# 1     AIM  Available to internal market  E7000
# 2     AIM  Available to internal market  E7000
# 3     AIM  Available to internal market  E7000
# ...

# %%
df.shape
# Out:
# (339, 21)

# %%
# Lets try using the API instead

# %%
# %pip install eurostat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import eurostat

df = eurostat.get_data_df("nrg_pc_204")  # example electricity price dataset
df.head()
# Out:
#   freq   siec      nrg_cons unit    tax currency geo\TIME_PERIOD  2007-S1  \
# 0    S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AL      NaN
# 1    S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AT      NaN
# 2    S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BA      NaN
# 3    S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BE      NaN
# 4    S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BG      NaN
#
#    2007-S2  2008-S1  ...  2021-S1  2021-S2  2022-S1  2022-S2  2023-S1  \
# 0      NaN      NaN  ...   0.0925   0.0937   0.0941   0.0976   0.1010
# 1   0.2008   0.2005  ...   0.2650   0.2787   0.2616   0.2614   0.2988
# 2      NaN      NaN  ...   0.0980   0.0970   0.0996   0.1003   0.1043
# 3   0.1867   0.2172  ...   0.2910   0.3161   0.3633   0.4586   0.4559
# 4   0.0721   0.0731  ...   0.1045   0.1104   0.1110   0.1147   0.1146
#
#    2023-S2  2024-S1  2024-S2  2025-S1  2025-S2
# 0   0.1089   0.1114   0.1150   0.1156   0.1175
# ...

# %%
df.shape
# Out:
# (2196, 45)

# %%
df.columns
# Out:
# Index(['freq', 'siec', 'nrg_cons', 'unit', 'tax', 'currency',
#        'geo\TIME_PERIOD', '2007-S1', '2007-S2', '2008-S1', '2008-S2',
#        '2009-S1', '2009-S2', '2010-S1', '2010-S2', '2011-S1', '2011-S2',
#        '2012-S1', '2012-S2', '2013-S1', '2013-S2', '2014-S1', '2014-S2',
#        '2015-S1', '2015-S2', '2016-S1', '2016-S2', '2017-S1', '2017-S2',
#        '2018-S1', '2018-S2', '2019-S1', '2019-S2', '2020-S1', '2020-S2',
#        '2021-S1', '2021-S2', '2022-S1', '2022-S2', '2023-S1', '2023-S2',
#        '2024-S1', '2024-S2', '2025-S1', '2025-S2'],
#       dtype='str')

# %%
df_melted = df.melt(
    id_vars=['freq', 'siec', 'nrg_cons', 'unit', 'tax', 'currency', 'geo\\TIME_PERIOD'],
    var_name='period',
    value_name='value'
)

# %%
df_melted
# Out:
#       freq   siec      nrg_cons unit    tax currency geo\TIME_PERIOD   period  \
# 0        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AL  2007-S1
# 1        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AT  2007-S1
# 2        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BA  2007-S1
# 3        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BE  2007-S1
# 4        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BG  2007-S1
# ...    ...    ...           ...  ...    ...      ...             ...      ...
# 83443    S  E7000       TOT_KWH  KWH  X_VAT      PPS              RS  2025-S2
# 83444    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SE  2025-S2
# 83445    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SI  2025-S2
# 83446    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SK  2025-S2
# 83447    S  E7000       TOT_KWH  KWH  X_VAT      PPS              TR  2025-S2
#
#         value
# 0         NaN
# ...

# %%
df_melted[['year', 'semester']] = df_melted['period'].str.split('-', expand=True)

# %%
df_melted
# Out:
#       freq   siec      nrg_cons unit    tax currency geo\TIME_PERIOD   period  \
# 0        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AL  2007-S1
# 1        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AT  2007-S1
# 2        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BA  2007-S1
# 3        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BE  2007-S1
# 4        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BG  2007-S1
# ...    ...    ...           ...  ...    ...      ...             ...      ...
# 83443    S  E7000       TOT_KWH  KWH  X_VAT      PPS              RS  2025-S2
# 83444    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SE  2025-S2
# 83445    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SI  2025-S2
# 83446    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SK  2025-S2
# 83447    S  E7000       TOT_KWH  KWH  X_VAT      PPS              TR  2025-S2
#
#         value  year semester
# ...

# %%
df = df.rename(columns={'geo\\TIME_PERIOD': 'geo'})

# %%
df
# Out:
#      freq   siec      nrg_cons unit    tax currency geo  2007-S1  2007-S2  \
# 0       S  E7000  KWH1000-2499  KWH  I_TAX      EUR  AL      NaN      NaN
# 1       S  E7000  KWH1000-2499  KWH  I_TAX      EUR  AT      NaN   0.2008
# 2       S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BA      NaN      NaN
# 3       S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BE      NaN   0.1867
# 4       S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BG      NaN   0.0721
# ...   ...    ...           ...  ...    ...      ...  ..      ...      ...
# 2191    S  E7000       TOT_KWH  KWH  X_VAT      PPS  RS      NaN      NaN
# 2192    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SE      NaN      NaN
# 2193    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SI      NaN      NaN
# 2194    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SK      NaN      NaN
# 2195    S  E7000       TOT_KWH  KWH  X_VAT      PPS  TR      NaN      NaN
#
#       2008-S1  ...  2021-S1  2021-S2  2022-S1  2022-S2  2023-S1  2023-S2  \
# ...

# %%
df_melted
# Out:
#       freq   siec      nrg_cons unit    tax currency geo\TIME_PERIOD   period  \
# 0        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AL  2007-S1
# 1        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              AT  2007-S1
# 2        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BA  2007-S1
# 3        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BE  2007-S1
# 4        S  E7000  KWH1000-2499  KWH  I_TAX      EUR              BG  2007-S1
# ...    ...    ...           ...  ...    ...      ...             ...      ...
# 83443    S  E7000       TOT_KWH  KWH  X_VAT      PPS              RS  2025-S2
# 83444    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SE  2025-S2
# 83445    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SI  2025-S2
# 83446    S  E7000       TOT_KWH  KWH  X_VAT      PPS              SK  2025-S2
# 83447    S  E7000       TOT_KWH  KWH  X_VAT      PPS              TR  2025-S2
#
#         value  year semester
# ...

# %%
df_melted = df_melted.rename(columns={'geo\\TIME_PERIOD': 'geo'})

# %%
df_melted
# Out:
#       freq   siec      nrg_cons unit    tax currency geo   period   value  \
# 0        S  E7000  KWH1000-2499  KWH  I_TAX      EUR  AL  2007-S1     NaN
# 1        S  E7000  KWH1000-2499  KWH  I_TAX      EUR  AT  2007-S1     NaN
# 2        S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BA  2007-S1     NaN
# 3        S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BE  2007-S1     NaN
# 4        S  E7000  KWH1000-2499  KWH  I_TAX      EUR  BG  2007-S1     NaN
# ...    ...    ...           ...  ...    ...      ...  ..      ...     ...
# 83443    S  E7000       TOT_KWH  KWH  X_VAT      PPS  RS  2025-S2  0.1742
# 83444    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SE  2025-S2  0.1441
# 83445    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SI  2025-S2  0.1973
# 83446    S  E7000       TOT_KWH  KWH  X_VAT      PPS  SK  2025-S2  0.1970
# 83447    S  E7000       TOT_KWH  KWH  X_VAT      PPS  TR  2025-S2  0.1650
#
#        year semester
# 0      2007       S1
# 1      2007       S1
# ...

# %%
df_melted['value'].isna().sum() # There are 18.036 null values in this dataset (not all countries report all years / some combinations (geo + tax + unit) don’t exist for early periods)
# Out:
# np.int64(18036)

# %%
df["currency"].unique()
# Out:
# <StringArray>
# ['EUR', 'NAC', 'PPS']
# Length: 3, dtype: str

# %% [markdown]
# Code	Meaning	                    Use case
# EUR	    Euro	                    real price in euros
# PPS	    Purchasing Power Standard	cross-country comparison
# NAC	    National Currency	        original local currency

# %%
df["geo"].unique()
# Out:
# <StringArray>
# [       'AL',        'AT',        'BA',        'BE',        'BG',        'CY',
#         'CZ',        'DE',        'DK',        'EA',        'EE',        'EL',
#         'ES', 'EU27_2020',        'FI',        'FR',        'GE',        'HR',
#         'HU',        'IE',        'IS',        'IT',        'LI',        'LT',
#         'LU',        'LV',        'MD',        'ME',        'MK',        'MT',
#         'NL',        'NO',        'PL',        'PT',        'RO',        'RS',
#         'SE',        'SI',        'SK',        'TR',        'UA',        'UK',
#         'XK']
# Length: 43, dtype: str

# %%
df_melted.describe()
# Out:
#               value
# count  65412.000000
# mean       0.935427
# std        4.141038
# min       -3.514400
# 25%        0.127200
# 50%        0.177100
# 75%        0.264600
# max       66.530000

# %%
df_eur = df_melted[df_melted["currency"] == "EUR"] # Filtering by only EUR currency

# %%
df_eur.describe()
# Out:
#               value
# count  22753.000000
# mean       0.166418
# std        0.092626
# min       -0.925800
# 25%        0.099900
# 50%        0.143700
# 75%        0.208500
# max        0.836200

# %%
df_eur["value"].mode()
# Out:
# 0    0.0963
# Name: value, dtype: float64

# %%
df_eur.shape
# Out:
# (29184, 11)

# %%
df_eur["value"].isnull().sum()
# Out:
# np.int64(6431)

# %%
df_eur = df_eur.dropna(subset=['value'])

# %%
df_eur["value"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_eur.shape
# Out:
# (22753, 11)

# %%
df_eur.head()
# Out:
#    freq   siec      nrg_cons unit    tax currency        geo   period   value  \
# 6     S  E7000  KWH1000-2499  KWH  I_TAX      EUR         CZ  2007-S1  0.1573
# 7     S  E7000  KWH1000-2499  KWH  I_TAX      EUR         DE  2007-S1  0.2258
# 9     S  E7000  KWH1000-2499  KWH  I_TAX      EUR         EA  2007-S1  0.2138
# 13    S  E7000  KWH1000-2499  KWH  I_TAX      EUR  EU27_2020  2007-S1  0.1974
# 17    S  E7000  KWH1000-2499  KWH  I_TAX      EUR         HR  2007-S1  0.1223
#
#     year semester
# 6   2007       S1
# 7   2007       S1
# 9   2007       S1
# 13  2007       S1
# 17  2007       S1

# %%
df_eur = df_eur.set_index("geo")

# %%
df_eur.head()
# Out:
#           freq   siec      nrg_cons unit    tax currency   period   value  \
# geo
# CZ           S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.1573
# DE           S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.2258
# EA           S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.2138
# EU27_2020    S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.1974
# HR           S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.1223
#
#            year semester
# geo
# CZ         2007       S1
# DE         2007       S1
# EA         2007       S1
# EU27_2020  2007       S1
# HR         2007       S1

# %%
df_eur = df_eur.loc[df_eur.index != "EU27_2020"] #Excluding EU27_2020 from country

# %%
df_eur
# Out:
#     freq   siec      nrg_cons unit    tax currency   period   value  year  \
# geo
# CZ     S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.1573  2007
# DE     S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.2258  2007
# EA     S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.2138  2007
# HR     S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.1223  2007
# LU     S  E7000  KWH1000-2499  KWH  I_TAX      EUR  2007-S1  0.2219  2007
# ..   ...    ...           ...  ...    ...      ...      ...     ...   ...
# SE     S  E7000       TOT_KWH  KWH  X_VAT      EUR  2025-S2  0.1756  2025
# SI     S  E7000       TOT_KWH  KWH  X_VAT      EUR  2025-S2  0.1721  2025
# SK     S  E7000       TOT_KWH  KWH  X_VAT      EUR  2025-S2  0.1580  2025
# TR     S  E7000       TOT_KWH  KWH  X_VAT      EUR  2025-S2  0.0617  2025
# XK     S  E7000       TOT_KWH  KWH  X_VAT      EUR  2025-S2  0.0871  2025
#
#     semester
# geo
# CZ        S1
# DE        S1
# EA        S1
# ...

# %%
df_eur.to_csv("eurostat_electricity_clean.csv")

# %%
# Merging datasets

# %%
# Load the dataset
import pandas as pd

# Load datasets
emissions = pd.read_csv(
    "https://github.com/Orgo4ever/data-wrangling-project/blob/main/clean_eurostat_power_sector_emissions.csv?raw=true"
)

ai_adoption = pd.read_csv(
    "https://github.com/Orgo4ever/data-wrangling-project/blob/main/ai_adoption_cleaned.csv?raw=true"
)

renewable = pd.read_csv(
    "https://github.com/Orgo4ever/data-wrangling-project/blob/main/cleaned_renewable_energy.csv?raw=true"
)

datacenter = pd.read_csv(
    "https://github.com/Orgo4ever/data-wrangling-project/blob/main/eu_facilities_cleaned.csv?raw=true"
)

# %%
for df in [emissions_subset, renewable_subset, ai_subset]:
    df["geo"] = df["geo"].astype(str).str.strip().str.upper()
    df["year"] = pd.to_numeric(df["year"], errors="coerce")

# Keep one row per country-year in each dataset
emissions_subset = (
    emissions_subset
    .groupby(["geo", "year"], as_index=False)["emissions"]
    .mean()
)

renewable_subset = (
    renewable_subset
    .groupby(["geo", "year"], as_index=False)["renewable_energy_share"]
    .mean()
)

ai_subset = (
    ai_subset
    .groupby(["geo", "year"], as_index=False)["ai_adoption_pct"]
    .mean()
)

# Start with AI adoption so all AI years, including 2025, are kept
grouped_df = (
    ai_subset
    .merge(
        renewable_subset,
        on=["geo", "year"],
        how="left"
 )
    .merge(
        emissions_subset,
        on=["geo", "year"],
        how="left"
 )
)

# Add country names
grouped_df["country_name"] = grouped_df["geo"].map(country_names)

# Sort and reset index
grouped_df = (
    grouped_df
    .sort_values(["geo", "year"])
    .reset_index(drop=True)
)

# Check whether 2025 is included
print("Latest year in AI dataset:", ai_subset["year"].max())
print("Latest year in grouped dataframe:", grouped_df["year"].max())

print(grouped_df.tail())
# Out:
# Latest year in AI dataset: 2025
# Latest year in grouped dataframe: 2025
#     geo  year  ai_adoption_pct  renewable_energy_share     emissions  \
# 126  SK  2025            18.00                     NaN           NaN
# 127  TR  2021             2.69                     NaN  79097.198180
# 128  TR  2023             5.51                     NaN  76613.496960
# 129  TR  2024             4.42                     NaN  80135.840785
# 130  TR  2025             7.41                     NaN           NaN
#
#     country_name
# 126     Slovakia
# 127      Türkiye
# 128      Türkiye
# 129      Türkiye
# 130      Türkiye

# %%
grouped_df
# Out:
#     geo  year   emissions  renewable_energy_share  ai_adoption_pct
# 0    AT  2021     8.56969                  34.643             8.83
# 1    AT  2023     7.18464                  41.600            10.79
# 2    AT  2024     7.14749                  42.951            20.27
# 3    BE  2021    18.01829                  13.017            10.32
# 4    BE  2023    15.52537                  14.673            13.81
# ..   ..   ...         ...                     ...              ...
# 163  SI  2023  3291.23000                  25.066            11.37
# 164  SI  2024  3615.51000                  25.001            20.89
# 165  SK  2021  7263.51000                  17.419             5.19
# 166  SK  2023  6353.16000                  16.991             7.04
# 167  SK  2024  5296.53000                  18.092            10.78
#
# [168 rows x 5 columns]

# %%
# Select relevant columns
emissions_subset = emissions[["geo", "year", "emissions"]]

renewable_subset = renewable[[
    "geo",
    "year",
    "renewable_energy_share"
]]

ai_subset = ai_adoption[[
    "country_code",
    "year",
    "ai_adoption_pct"
]].rename(columns={"country_code": "geo"})

# Merge datasets
grouped_df = (
    emissions_subset
    .merge(
        renewable_subset,
        on=["geo", "year"],
        how="inner"
    )
    .merge(
        ai_subset,
        on=["geo", "year"],
        how="inner"
    )
)

# View result
print(grouped_df.head())
print(grouped_df.shape)
# Out:
#   geo  year  emissions  renewable_energy_share  ai_adoption_pct
# 0  AT  2021    8.56969                  34.643             8.83
# 1  AT  2023    7.18464                  41.600            10.79
# 2  AT  2024    7.14749                  42.951            20.27
# 3  BE  2021   18.01829                  13.017            10.32
# 4  BE  2023   15.52537                  14.673            13.81
# (168, 5)

# %%
grouped_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   geo                     168 non-null    str
#  1   year                    168 non-null    int64
#  2   emissions               168 non-null    float64
#  3   renewable_energy_share  168 non-null    float64
#  4   ai_adoption_pct         168 non-null    float64
# dtypes: float64(3), int64(1), str(1)
# memory usage: 6.7 KB

# %%
grouped_df['year'].min()  # Check the minimum year in the dataset
# Out:
# np.int64(2021)

# %%
grouped_df['year'].max()  # Check the maximum year in the dataset
# Out:
# np.int64(2024)

# %% [markdown]
# Part 1 — Mapping Europe's AI Boom
#
# Questions
#
# •	Which countries have the highest AI adoption?
#
# •	How has AI adoption evolved over time?
#
# Visualizations
#
# •	Top 10 countries
#
# •	Bar chart
#
# •	Line chart (if multiple years)
#
# Insight
#
# Identify Europe's AI leaders.

# %%
import pandas as pd

ai_clean = (
    ai_adoption
    .groupby(["country_code", "year"], as_index=False)
    .agg({"ai_adoption_pct": "mean"})
    .rename(columns={"country_code": "geo"})
)

latest_year = ai_clean["year"].max()

top10 = (
    ai_clean[ai_clean["year"] == latest_year]
    .sort_values("ai_adoption_pct", ascending=False)
    .head(10)
)

top10
# Out:
#     geo  year  ai_adoption_pct
# 34   DK  2025            42.03
# 50   FI  2025            37.82
# 118  SE  2025            35.04
# 14   BE  2025            34.54
# 78   LU  2025            33.61
# 94   NL  2025            33.21
# 6    AT  2025            29.95
# 98   NO  2025            28.89
# 30   DE  2025            25.97
# 38   EE  2025            23.40

# %%
import matplotlib.pyplot as plt

# Sort so the highest-adoption country appears at the top
top10_plot = top10.sort_values("ai_adoption_pct", ascending=True)

plt.figure(figsize=(10, 6))

plt.barh(
    top10_plot["geo"],
    top10_plot["ai_adoption_pct"]
)

plt.title(f"Top 10 Countries by AI Company Adoption in {latest_year}")
plt.xlabel("AI adoption (%)")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
ai_adoption.columns.tolist()
# Out:
# ['freq',
#  'size_emp',
#  'nace_r2',
#  'indic_is',
#  'unit',
#  'country_code',
#  'year',
#  'ai_adoption_pct']

# %%
ai_adoption.head()
# Out:
#   freq size_emp       nace_r2   indic_is    unit country_code  year  \
# 0    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT           AL  2021
# 1    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT           AL  2024
# 2    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT           AL  2025
# 3    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT           AT  2021
# 4    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT           AT  2023
#
#    ai_adoption_pct
# 0             3.67
# 1             8.91
# 2             8.99
# 3             8.83
# 4            10.79

# %%
ai_adoption = ai_adoption.rename(columns={"country_code": "geo"})

# %%
ai_adoption.head()
# Out:
#   freq size_emp       nace_r2   indic_is    unit geo  year  ai_adoption_pct
# 0    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT  AL  2021             3.67
# 1    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT  AL  2024             8.91
# 2    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT  AL  2025             8.99
# 3    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT  AT  2021             8.83
# 4    A     GE10  C10-S951_X_K  E_AI_TANY  PC_ENT  AT  2023            10.79

# %%
trend = ai_adoption.groupby(["year", "geo"])["ai_adoption_pct"].mean().reset_index()

# %%
top_countries = (
    ai_adoption.groupby("geo")["ai_adoption_pct"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .index
)

# %%
trend_top5 = trend[trend["geo"].isin(top5)]

# %%
trend_top5
# Out:
#      year geo  ai_adoption_pct
# 3    2021  BE            10.32
# 8    2021  DK            23.89
# 12   2021  FI            15.79
# 19   2021  LU            13.00
# 23   2021  NL            13.10
# 35   2023  BE            13.81
# 40   2023  DK            15.17
# 44   2023  FI            15.10
# 51   2023  LU            14.45
# 55   2023  NL            14.10
# 68   2024  BE            24.71
# 73   2024  DK            27.58
# 77   2024  FI            24.37
# 84   2024  LU            23.73
# 88   2024  NL            23.06
# 101  2025  BE            34.54
# 106  2025  DK            42.03
# 110  2025  FI            37.82
# 117  2025  LU            33.61
# 121  2025  NL            33.21

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for country in trend_top5["geo"].unique():
    data = trend_top5[trend_top5["geo"] == country]
    plt.plot(
        data["year"],
        data["ai_adoption_pct"],
        marker="o",
        label=country
    )

plt.title("AI Adoption Over Time in Top 5 European Countries")
plt.xlabel("Year")
plt.ylabel("AI Adoption (%)")
plt.legend(title="Country")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# The main insight is:
#
# While a few leading countries experienced temporary declines between 2021 and 2023, the overall trend across Europe remained positive, with AI adoption accelerating strongly after 2023.
#
# AI adoption grew significantly over the study period, indicating a rapid expansion of AI use among European businesses. Denmark (DK) maintained the highest adoption levels and reached over 42% in 2025. Belgium (BE), Finland (FI), Luxembourg (LU), and the Netherlands (NL) also experienced strong growth, particularly after 2023, suggesting accelerated AI integration among European businesses.

# %% [markdown]
# AI adoption = The percentage of enterprises (companies) that use at least one AI technology in their business operations.

# %%
europe_trend = (
    ai_adoption.groupby("year")["ai_adoption_pct"]
    .mean()
    .reset_index()
)

print(europe_trend)
# Out:
#    year  ai_adoption_pct
# 0  2021         7.012727
# 1  2023         7.807812
# 2  2024        13.359394
# 3  2025        19.270606

# %% [markdown]
# Part 3 — AI and Renewable Energy
#
# Questions
#
# •	Are AI-leading countries investing in renewable energy?
#
# Variables
#
# •	AI Adoption
#
# •	Renewable Energy %
#
# Visualizations
#
# Scatter plot
#
# Ranking table
#
# Insight
#
# Countries may be supporting AI growth with cleaner energy.

# %%
renewable.columns
# Out:
# Index(['geo', 'country', 'year', 'renewable_energy_share'], dtype='str')

# %%
renewable.head()
# Out:
#   geo  country  year  renewable_energy_share
# 0  AL  Albania  2015                  34.913
# 1  AL  Albania  2016                  36.953
# 2  AL  Albania  2017                  35.776
# 3  AL  Albania  2018                  36.572
# 4  AL  Albania  2019                  38.042

# %%
grouped_df.head()
# Out:
#   geo  year  emissions  renewable_energy_share  ai_adoption_pct
# 0  AT  2021    8.56969                  34.643             8.83
# 1  AT  2023    7.18464                  41.600            10.79
# 2  AT  2024    7.14749                  42.951            20.27
# 3  BE  2021   18.01829                  13.017            10.32
# 4  BE  2023   15.52537                  14.673            13.81
