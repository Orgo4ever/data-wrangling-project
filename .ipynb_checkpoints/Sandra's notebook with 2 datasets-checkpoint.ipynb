# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Orgo4ever/data-wrangling-project/main/Data/Raw%20data/eurostat_renewable_energy_share.csv"

df = pd.read_csv(url)

df.head()
# Out:
#   STRUCTURE                        STRUCTURE_ID  \
# 0  dataflow  ESTAT:NRG_IND_REN$DEFAULTVIEW(1.0)
# 1  dataflow  ESTAT:NRG_IND_REN$DEFAULTVIEW(1.0)
# 2  dataflow  ESTAT:NRG_IND_REN$DEFAULTVIEW(1.0)
# 3  dataflow  ESTAT:NRG_IND_REN$DEFAULTVIEW(1.0)
# 4  dataflow  ESTAT:NRG_IND_REN$DEFAULTVIEW(1.0)
#
#                            STRUCTURE_NAME freq Time frequency nrg_bal  \
# 0  Share of energy from renewable sources    A         Annual     REN
# 1  Share of energy from renewable sources    A         Annual     REN
# 2  Share of energy from renewable sources    A         Annual     REN
# 3  Share of energy from renewable sources    A         Annual     REN
# 4  Share of energy from renewable sources    A         Annual     REN
#
#                Energy balance unit Unit of measure geo  \
# 0  Renewable energy - overall   PC      Percentage  AL
# 1  Renewable energy - overall   PC      Percentage  AL
# 2  Renewable energy - overall   PC      Percentage  AL
# 3  Renewable energy - overall   PC      Percentage  AL
# 4  Renewable energy - overall   PC      Percentage  AL
#
#   Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Albania         2015   NaN     34.913
# 1                         Albania         2016   NaN     36.953
# 2                         Albania         2017   NaN     35.776
# 3                         Albania         2018   NaN     36.572
# 4                         Albania         2019   NaN     38.042
#
#    Observation value  OBS_FLAG  Observation status (Flag) V2 structure  \
# 0                NaN       NaN                                     NaN
# 1                NaN       NaN                                     NaN
# 2                NaN       NaN                                     NaN
# 3                NaN       NaN                                     NaN
# 4                NaN       NaN                                     NaN
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN

# %%
df.isnull()
# Out:
#      STRUCTURE  STRUCTURE_ID  STRUCTURE_NAME   freq  Time frequency  nrg_bal  \
# 0        False         False           False  False           False    False
# 1        False         False           False  False           False    False
# 2        False         False           False  False           False    False
# 3        False         False           False  False           False    False
# 4        False         False           False  False           False    False
# ..         ...           ...             ...    ...             ...      ...
# 377      False         False           False  False           False    False
# 378      False         False           False  False           False    False
# 379      False         False           False  False           False    False
# 380      False         False           False  False           False    False
# 381      False         False           False  False           False    False
#
#      Energy balance   unit  Unit of measure    geo  \
# 0             False  False            False  False
# 1             False  False            False  False
# 2             False  False            False  False
# 3             False  False            False  False
# 4             False  False            False  False
# ..              ...    ...              ...    ...
# 377           False  False            False  False
# 378           False  False            False  False
# 379           False  False            False  False
# 380           False  False            False  False
# 381           False  False            False  False
#
#      Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0                              False        False  True      False
# 1                              False        False  True      False
# 2                              False        False  True      False
# 3                              False        False  True      False
# 4                              False        False  True      False
# ..                               ...          ...   ...        ...
# 377                            False        False  True      False
# 378                            False        False  True      False
# 379                            False        False  True      False
# 380                            False        False  True      False
# 381                            False        False  True      False
#
#      Observation value  OBS_FLAG  Observation status (Flag) V2 structure  \
# 0                 True      True                                    True
# 1                 True      True                                    True
# 2                 True      True                                    True
# 3                 True      True                                    True
# 4                 True      True                                    True
# ..                 ...       ...                                     ...
# 377               True      True                                    True
# 378               True      True                                    True
# 379               True      True                                    True
# 380               True      True                                    True
# 381               True      True                                    True
#
#      CONF_STATUS  Confidentiality status (flag)
# 0           True                           True
# 1           True                           True
# 2           True                           True
# 3           True                           True
# 4           True                           True
# ..           ...                            ...
# 377         True                           True
# 378         True                           True
# 379         True                           True
# 380         True                           True
# 381         True                           True
#
# [382 rows x 19 columns]

# %%
df.isnull().sum() / len(df) * 100
# Out:
# STRUCTURE                                   0.0
# STRUCTURE_ID                                0.0
# STRUCTURE_NAME                              0.0
# freq                                        0.0
# Time frequency                              0.0
# nrg_bal                                     0.0
# Energy balance                              0.0
# unit                                        0.0
# Unit of measure                             0.0
# geo                                         0.0
# Geopolitical entity (reporting)             0.0
# TIME_PERIOD                                 0.0
# Time                                      100.0
# OBS_VALUE                                   0.0
# Observation value                         100.0
# OBS_FLAG                                  100.0
# Observation status (Flag) V2 structure    100.0
# CONF_STATUS                               100.0
# Confidentiality status (flag)             100.0
# dtype: float64

# %%
df.isna().sum()
# Out:
# STRUCTURE                                   0
# STRUCTURE_ID                                0
# STRUCTURE_NAME                              0
# freq                                        0
# Time frequency                              0
# nrg_bal                                     0
# Energy balance                              0
# unit                                        0
# Unit of measure                             0
# geo                                         0
# Geopolitical entity (reporting)             0
# TIME_PERIOD                                 0
# Time                                      382
# OBS_VALUE                                   0
# Observation value                         382
# OBS_FLAG                                  382
# Observation status (Flag) V2 structure    382
# CONF_STATUS                               382
# Confidentiality status (flag)             382
# dtype: int64

# %%
df = df.dropna(axis=1, how="all")

# %%
df.shape
# Out:
# (382, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   STRUCTURE                        382 non-null    str
#  1   STRUCTURE_ID                     382 non-null    str
#  2   STRUCTURE_NAME                   382 non-null    str
#  3   freq                             382 non-null    str
#  4   Time frequency                   382 non-null    str
#  5   nrg_bal                          382 non-null    str
#  6   Energy balance                   382 non-null    str
#  7   unit                             382 non-null    str
#  8   Unit of measure                  382 non-null    str
#  9   geo                              382 non-null    str
#  10  Geopolitical entity (reporting)  382 non-null    str
#  11  TIME_PERIOD                      382 non-null    int64
#  12  OBS_VALUE                        382 non-null    float64
# dtypes: float64(1), int64(1), str(11)
# memory usage: 38.9 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# STRUCTURE                            1
# STRUCTURE_ID                         1
# STRUCTURE_NAME                       1
# freq                                 1
# Time frequency                       1
# nrg_bal                              1
# Energy balance                       1
# unit                                 1
# Unit of measure                      1
# geo                                 40
# Geopolitical entity (reporting)     40
# TIME_PERIOD                         10
# OBS_VALUE                          377
# dtype: int64

# %%
df = df.drop(columns=[
    "STRUCTURE",
    "STRUCTURE_ID",
    "STRUCTURE_NAME",
    "freq",
    "Time frequency",
    "nrg_bal",
    "Energy balance",
    "unit",
    "Unit of measure"
])

# %%
df = df.rename(columns={
    "Geopolitical entity (reporting)": "country",
    "TIME_PERIOD": "year",
    "OBS_VALUE": "renewable_energy_share"
})

# %%
df.head()
# Out:
#   geo  country  year  renewable_energy_share
# 0  AL  Albania  2015                  34.913
# 1  AL  Albania  2016                  36.953
# 2  AL  Albania  2017                  35.776
# 3  AL  Albania  2018                  36.572
# 4  AL  Albania  2019                  38.042

# %%
df.head(10)
# Out:
#   geo  country  year  renewable_energy_share
# 0  AL  Albania  2015                  34.913
# 1  AL  Albania  2016                  36.953
# 2  AL  Albania  2017                  35.776
# 3  AL  Albania  2018                  36.572
# 4  AL  Albania  2019                  38.042
# 5  AL  Albania  2020                  45.015
# 6  AL  Albania  2021                  41.389
# 7  AL  Albania  2022                  44.076
# 8  AL  Albania  2023                  46.620
# 9  AL  Albania  2024                  43.111

# %%
df.tail()
# Out:
#     geo  country  year  renewable_energy_share
# 377  XK  Kosovo*  2020                  24.401
# 378  XK  Kosovo*  2021                  22.061
# 379  XK  Kosovo*  2022                  18.773
# 380  XK  Kosovo*  2023                  20.215
# 381  XK  Kosovo*  2024                  18.020

# %%
df
# Out:
#     geo  country  year  renewable_energy_share
# 0    AL  Albania  2015                  34.913
# 1    AL  Albania  2016                  36.953
# 2    AL  Albania  2017                  35.776
# 3    AL  Albania  2018                  36.572
# 4    AL  Albania  2019                  38.042
# ..   ..      ...   ...                     ...
# 377  XK  Kosovo*  2020                  24.401
# 378  XK  Kosovo*  2021                  22.061
# 379  XK  Kosovo*  2022                  18.773
# 380  XK  Kosovo*  2023                  20.215
# 381  XK  Kosovo*  2024                  18.020
#
# [382 rows x 4 columns]

# %%
df.to_csv("cleaned_renewable_energy.csv", index=False)

# %%
df = df.rename(columns={"geo": "country_code"})

# %%
df = df.sort_values(["country", "year"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 382 entries, 0 to 351
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country_code            382 non-null    str
#  1   country                 382 non-null    str
#  2   year                    382 non-null    int64
#  3   renewable_energy_share  382 non-null    float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 14.9 KB

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country_code            382 non-null    str
#  1   country                 382 non-null    str
#  2   year                    382 non-null    int64
#  3   renewable_energy_share  382 non-null    float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 12.1 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["country"].unique()
# Out:
# <StringArray>
# [                                  'Albania',
#                                    'Austria',
#                                    'Belgium',
#                     'Bosnia and Herzegovina',
#                                   'Bulgaria',
#                                    'Croatia',
#                                     'Cyprus',
#                                    'Czechia',
#                                    'Denmark',
#                                    'Estonia',
#       'Euro area – 20 countries (2023-2025)',
#       'Euro area – 21 countries (from 2026)',
#  'European Union - 27 countries (from 2020)',
#                                    'Finland',
#                                     'France',
#                                    'Georgia',
#                                    'Germany',
#                                     'Greece',
#                                    'Hungary',
#                                    'Iceland',
#                                    'Ireland',
#                                      'Italy',
#                                    'Kosovo*',
#                                     'Latvia',
#                                  'Lithuania',
#                                 'Luxembourg',
#                                      'Malta',
#                                    'Moldova',
#                                 'Montenegro',
#                                'Netherlands',
#                            'North Macedonia',
#                                     'Norway',
#                                     'Poland',
#                                   'Portugal',
#                                    'Romania',
#                                     'Serbia',
#                                   'Slovakia',
#                                   'Slovenia',
#                                      'Spain',
#                                     'Sweden']
# Length: 40, dtype: str

# %%
df["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
df["renewable_energy_share"].describe()
# Out:
# count    382.000000
# mean      27.420469
# std       16.146516
# min        4.987000
# 25%       17.132000
# 50%       22.572500
# 75%       35.093750
# max       83.725000
# Name: renewable_energy_share, dtype: float64

# %%
#summary

Here's a short summary of your cleaned dataset:

Dataset overview
Rows: 382
Columns: 4
Missing values: None ✅
Duplicate information: Each row represents one country in one year.
Variables
Column	Type	Description
geo	Text	Country code (e.g. AL)
country	Text	Country name
year	Integer	Year of the observation
renewable_energy_share	Float	Percentage of renewable energy share
Time coverage
From: 2015
To: 2024
Countries: 40
Renewable energy share statistics
Average: 27.42%
Median: 22.57%
Minimum: 4.99%
Maximum: 83.73%
25th percentile: 17.13%
75th percentile: 35.09%
Data quality
✅ No missing values.
✅ Correct data types (year as integer and renewable_energy_share as numeric).
✅ Clean and ready for analysis and visualization.
Possible analyses

With this dataset you can:

Analyze how renewable energy share changes over time (2015–2024).
Compare countries' renewable energy adoption.
Identify countries with the highest and lowest renewable energy shares.
Calculate trends or growth rates by country.
Create line charts, bar charts, heatmaps, or maps of renewable energy usage.

This dataset is well-structured for time series and cross-country comparisons.

# %%
#The next phase is EDA (Exploratory Data Analysis):

#1.How renewable is Europe's electricity? -> Which countries have the highest renewable energy share?
#2.Is Europe becoming greener over time? -> How has renewable energy share changed over time?
#3. Which countries are improving the fastest? -> hich countries have seen the biggest increase?
#These are all useful because they establish whether Europe's energy system is becoming cleaner—the context needed before talking about AI

# %%
#Then, when you merge with your AI dataset, you answer the real question:
    #·Where are AI data centers located?
    #·Do those countries rely on renewable energy?
    #·Is AI expanding in countries with cleaner electricity?
    #·Is renewable energy growing fast enough to support AI's increasing electricity demand?

# %%
#Think of your project like a story

#Chapter 1 – Renewable energy (this dataset)

    #Is Europe getting greener?

#Chapter 2 – AI infrastructure

    #Where is AI growing?

#Chapter 3 – Merge

    #Does AI growth align with clean energy, or is it increasing pressure on fossil-fuel-based electricity?

#That third chapter is where you answer "Is Europe's AI boom environmentally sustainable?" 
#The first two chapters provide the evidence needed to reach that conclusion.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Orgo4ever/data-wrangling-project/refs/heads/main/Data/Raw%20data/eurostat_power_sector_emissions.csv"

df2 = pd.read_csv(url)

df2.head()
# Out:
#   STRUCTURE                        STRUCTURE_ID  \
# 0  dataflow  ESTAT:ENV_AIR_GGE$DEFAULTVIEW(1.0)
# 1  dataflow  ESTAT:ENV_AIR_GGE$DEFAULTVIEW(1.0)
# 2  dataflow  ESTAT:ENV_AIR_GGE$DEFAULTVIEW(1.0)
# 3  dataflow  ESTAT:ENV_AIR_GGE$DEFAULTVIEW(1.0)
# 4  dataflow  ESTAT:ENV_AIR_GGE$DEFAULTVIEW(1.0)
#
#                               STRUCTURE_NAME freq Time frequency   unit  \
# 0  Greenhouse gas emissions by source sector    A         Annual  MIO_T
# 1  Greenhouse gas emissions by source sector    A         Annual  MIO_T
# 2  Greenhouse gas emissions by source sector    A         Annual  MIO_T
# 3  Greenhouse gas emissions by source sector    A         Annual  MIO_T
# 4  Greenhouse gas emissions by source sector    A         Annual  MIO_T
#
#   Unit of measure airpol Air pollutants and greenhouse gases src_crf  ... geo  \
# 0  Million tonnes    CH4                             Methane    CRF1  ...  AT
# 1  Million tonnes    CH4                             Methane    CRF1  ...  AT
# 2  Million tonnes    CH4                             Methane    CRF1  ...  AT
# 3  Million tonnes    CH4                             Methane    CRF1  ...  AT
# 4  Million tonnes    CH4                             Methane    CRF1  ...  AT
#
#   Geopolitical entity (reporting) TIME_PERIOD  Time  OBS_VALUE  \
# 0                         Austria        2015   NaN    0.03087
# 1                         Austria        2016   NaN    0.03084
# 2                         Austria        2017   NaN    0.03199
# 3                         Austria        2018   NaN    0.02887
# 4                         Austria        2019   NaN    0.02811
#
#    Observation value  OBS_FLAG  Observation status (Flag) V2 structure  \
# 0                NaN       NaN                                     NaN
# 1                NaN       NaN                                     NaN
# 2                NaN       NaN                                     NaN
# 3                NaN       NaN                                     NaN
# 4                NaN       NaN                                     NaN
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN
#
# [5 rows x 21 columns]

# %%
df2.isnull()
# Out:
#        STRUCTURE  STRUCTURE_ID  STRUCTURE_NAME   freq  Time frequency   unit  \
# 0          False         False           False  False           False  False
# 1          False         False           False  False           False  False
# 2          False         False           False  False           False  False
# 3          False         False           False  False           False  False
# 4          False         False           False  False           False  False
# ...          ...           ...             ...    ...             ...    ...
# 15995      False         False           False  False           False  False
# 15996      False         False           False  False           False  False
# 15997      False         False           False  False           False  False
# 15998      False         False           False  False           False  False
# 15999      False         False           False  False           False  False
#
#        Unit of measure  airpol  Air pollutants and greenhouse gases  src_crf  \
# 0                False   False                                False    False
# 1                False   False                                False    False
# 2                False   False                                False    False
# 3                False   False                                False    False
# 4                False   False                                False    False
# ...                ...     ...                                  ...      ...
# 15995            False   False                                False    False
# 15996            False   False                                False    False
# 15997            False   False                                False    False
# 15998            False   False                                False    False
# 15999            False   False                                False    False
#
#        ...    geo  Geopolitical entity (reporting)  TIME_PERIOD  Time  \
# 0      ...  False                            False        False  True
# 1      ...  False                            False        False  True
# 2      ...  False                            False        False  True
# 3      ...  False                            False        False  True
# 4      ...  False                            False        False  True
# ...    ...    ...                              ...          ...   ...
# 15995  ...  False                            False        False  True
# 15996  ...  False                            False        False  True
# 15997  ...  False                            False        False  True
# 15998  ...  False                            False        False  True
# 15999  ...  False                            False        False  True
#
#        OBS_VALUE  Observation value  OBS_FLAG  \
# 0          False               True      True
# 1          False               True      True
# 2          False               True      True
# 3          False               True      True
# 4          False               True      True
# ...          ...                ...       ...
# 15995      False               True      True
# 15996      False               True      True
# 15997      False               True      True
# 15998      False               True      True
# 15999      False               True      True
#
#        Observation status (Flag) V2 structure  CONF_STATUS  \
# 0                                        True         True
# 1                                        True         True
# 2                                        True         True
# 3                                        True         True
# 4                                        True         True
# ...                                       ...          ...
# 15995                                    True         True
# 15996                                    True         True
# 15997                                    True         True
# 15998                                    True         True
# 15999                                    True         True
#
#        Confidentiality status (flag)
# 0                               True
# 1                               True
# 2                               True
# 3                               True
# 4                               True
# ...                              ...
# 15995                           True
# 15996                           True
# 15997                           True
# 15998                           True
# 15999                           True
#
# [16000 rows x 21 columns]

# %%
df2.isnull().sum() / len(df2) * 100
# Out:
# STRUCTURE                                                                          0.0
# STRUCTURE_ID                                                                       0.0
# STRUCTURE_NAME                                                                     0.0
# freq                                                                               0.0
# Time frequency                                                                     0.0
# unit                                                                               0.0
# Unit of measure                                                                    0.0
# airpol                                                                             0.0
# Air pollutants and greenhouse gases                                                0.0
# src_crf                                                                            0.0
# Source sectors for greenhouse gas emissions (Common reporting format, UNFCCC)      0.0
# geo                                                                                0.0
# Geopolitical entity (reporting)                                                    0.0
# TIME_PERIOD                                                                        0.0
# Time                                                                             100.0
# OBS_VALUE                                                                          0.0
# Observation value                                                                100.0
# OBS_FLAG                                                                         100.0
# Observation status (Flag) V2 structure                                           100.0
# CONF_STATUS                                                                      100.0
# Confidentiality status (flag)                                                    100.0
# dtype: float64

# %%
df2.isna().sum()
# Out:
# STRUCTURE                                                                            0
# STRUCTURE_ID                                                                         0
# STRUCTURE_NAME                                                                       0
# freq                                                                                 0
# Time frequency                                                                       0
# unit                                                                                 0
# Unit of measure                                                                      0
# airpol                                                                               0
# Air pollutants and greenhouse gases                                                  0
# src_crf                                                                              0
# Source sectors for greenhouse gas emissions (Common reporting format, UNFCCC)        0
# geo                                                                                  0
# Geopolitical entity (reporting)                                                      0
# TIME_PERIOD                                                                          0
# Time                                                                             16000
# OBS_VALUE                                                                            0
# Observation value                                                                16000
# OBS_FLAG                                                                         16000
# Observation status (Flag) V2 structure                                           16000
# CONF_STATUS                                                                      16000
# Confidentiality status (flag)                                                    16000
# dtype: int64

# %%
df2 = df2.drop(columns=[
    "Time",
    "Observation value",
    "OBS_FLAG",
    "Observation status (Flag) V2 structure",
    "CONF_STATUS",
    "Confidentiality status (flag)"
])

# %%
df2 = df2.drop(columns=[
    "STRUCTURE",
    "STRUCTURE_ID",
    "STRUCTURE_NAME",
    "freq",
    "Time frequency",
    "unit",
    "Unit of measure"
])

# %%
df2 = df2.rename(columns={
    "Air pollutants and greenhouse gases": "gas_name",
    "airpol": "gas",
    "Source sectors for greenhouse gas emissions (Common reporting format, UNFCCC)": "sector_name",
    "src_crf": "sector",
    "Geopolitical entity (reporting)": "country",
    "TIME_PERIOD": "year",
    "OBS_VALUE": "emissions"
})

# %%
df2.duplicated().sum()
# Out:
# np.int64(35)

# %%
df2[df2.duplicated()]
# Out:
#             gas                  gas_name  sector  \
# 8810        CH4                   Methane  CRF1A1
# 8811        CH4                   Methane  CRF1A1
# 8812        CH4                   Methane  CRF1A1
# 8813        CH4                   Methane  CRF1A1
# 8814        CH4                   Methane  CRF1A1
# 8815        CH4                   Methane  CRF1A1
# 8816        CH4                   Methane  CRF1A1
# 8817        CH4                   Methane  CRF1A1
# 8818        CH4                   Methane  CRF1A1
# 8819        CH4                   Methane  CRF1A1
# 10410  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 10411  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 10412  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 10413  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 10415  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 10416  CH4_CO2E  Methane (CO2 equivalent)  CRF1A1
# 15210       N2O             Nitrous oxide  CRF1A1
# 15211       N2O             Nitrous oxide  CRF1A1
# 15212       N2O             Nitrous oxide  CRF1A1
# 15213       N2O             Nitrous oxide  CRF1A1
# 15214       N2O             Nitrous oxide  CRF1A1
# 15215       N2O             Nitrous oxide  CRF1A1
# 15216       N2O             Nitrous oxide  CRF1A1
# 15217       N2O             Nitrous oxide  CRF1A1
# 15218       N2O             Nitrous oxide  CRF1A1
# 15219       N2O             Nitrous oxide  CRF1A1
# 15261       N2O             Nitrous oxide  CRF1A1
# 15262       N2O             Nitrous oxide  CRF1A1
# 15263       N2O             Nitrous oxide  CRF1A1
# 15264       N2O             Nitrous oxide  CRF1A1
# 15265       N2O             Nitrous oxide  CRF1A1
# 15266       N2O             Nitrous oxide  CRF1A1
# 15267       N2O             Nitrous oxide  CRF1A1
# 15268       N2O             Nitrous oxide  CRF1A1
# 15269       N2O             Nitrous oxide  CRF1A1
#
#                                 sector_name geo  country  year  emissions
# 8810   Fuel combustion in energy industries  IS  Iceland  2015        0.0
# 8811   Fuel combustion in energy industries  IS  Iceland  2016        0.0
# 8812   Fuel combustion in energy industries  IS  Iceland  2017        0.0
# 8813   Fuel combustion in energy industries  IS  Iceland  2018        0.0
# 8814   Fuel combustion in energy industries  IS  Iceland  2019        0.0
# 8815   Fuel combustion in energy industries  IS  Iceland  2020        0.0
# 8816   Fuel combustion in energy industries  IS  Iceland  2021        0.0
# 8817   Fuel combustion in energy industries  IS  Iceland  2022        0.0
# 8818   Fuel combustion in energy industries  IS  Iceland  2023        0.0
# 8819   Fuel combustion in energy industries  IS  Iceland  2024        0.0
# 10410  Fuel combustion in energy industries  IS  Iceland  2015        0.0
# 10411  Fuel combustion in energy industries  IS  Iceland  2016        0.0
# 10412  Fuel combustion in energy industries  IS  Iceland  2017        0.0
# 10413  Fuel combustion in energy industries  IS  Iceland  2018        0.0
# 10415  Fuel combustion in energy industries  IS  Iceland  2020        0.0
# 10416  Fuel combustion in energy industries  IS  Iceland  2021        0.0
# 15210  Fuel combustion in energy industries  IS  Iceland  2015        0.0
# 15211  Fuel combustion in energy industries  IS  Iceland  2016        0.0
# 15212  Fuel combustion in energy industries  IS  Iceland  2017        0.0
# 15213  Fuel combustion in energy industries  IS  Iceland  2018        0.0
# 15214  Fuel combustion in energy industries  IS  Iceland  2019        0.0
# 15215  Fuel combustion in energy industries  IS  Iceland  2020        0.0
# 15216  Fuel combustion in energy industries  IS  Iceland  2021        0.0
# 15217  Fuel combustion in energy industries  IS  Iceland  2022        0.0
# 15218  Fuel combustion in energy industries  IS  Iceland  2023        0.0
# 15219  Fuel combustion in energy industries  IS  Iceland  2024        0.0
# 15261  Fuel combustion in energy industries  MT    Malta  2016        0.0
# 15262  Fuel combustion in energy industries  MT    Malta  2017        0.0
# 15263  Fuel combustion in energy industries  MT    Malta  2018        0.0
# 15264  Fuel combustion in energy industries  MT    Malta  2019        0.0
# 15265  Fuel combustion in energy industries  MT    Malta  2020        0.0
# 15266  Fuel combustion in energy industries  MT    Malta  2021        0.0
# 15267  Fuel combustion in energy industries  MT    Malta  2022        0.0
# 15268  Fuel combustion in energy industries  MT    Malta  2023        0.0
# 15269  Fuel combustion in energy industries  MT    Malta  2024        0.0

# %%
df2[df2.duplicated(keep=False)]
# Out:
#        gas       gas_name  sector                           sector_name geo  \
# 810    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 811    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 812    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 813    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 814    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# ...    ...            ...     ...                                   ...  ..
# 15265  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15266  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15267  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15268  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15269  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
#
#        country  year  emissions
# 810    Iceland  2015        0.0
# 811    Iceland  2016        0.0
# 812    Iceland  2017        0.0
# 813    Iceland  2018        0.0
# 814    Iceland  2019        0.0
# ...        ...   ...        ...
# 15265    Malta  2020        0.0
# 15266    Malta  2021        0.0
# 15267    Malta  2022        0.0
# 15268    Malta  2023        0.0
# 15269    Malta  2024        0.0
#
# [70 rows x 8 columns]

# %%
df2[df2.duplicated(keep=False)].sort_values(
    by=["gas", "sector", "geo", "year"]
)
# Out:
#        gas       gas_name  sector                           sector_name geo  \
# 810    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 8810   CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 811    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 8811   CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# 812    CH4        Methane  CRF1A1  Fuel combustion in energy industries  IS
# ...    ...            ...     ...                                   ...  ..
# 15267  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 7268   N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15268  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 7269   N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
# 15269  N2O  Nitrous oxide  CRF1A1  Fuel combustion in energy industries  MT
#
#        country  year  emissions
# 810    Iceland  2015        0.0
# 8810   Iceland  2015        0.0
# 811    Iceland  2016        0.0
# 8811   Iceland  2016        0.0
# 812    Iceland  2017        0.0
# ...        ...   ...        ...
# 15267    Malta  2022        0.0
# 7268     Malta  2023        0.0
# 15268    Malta  2023        0.0
# 7269     Malta  2024        0.0
# 15269    Malta  2024        0.0
#
# [70 rows x 8 columns]

# %%
df2 = df2.drop_duplicates()

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2["gas"].unique()

df2["sector"].unique()

df2["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
df2 = df2[df2["gas"] == "CO2"]

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.head()

df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gas          3200 non-null   str
#  1   gas_name     3200 non-null   str
#  2   sector       3200 non-null   str
#  3   sector_name  3200 non-null   str
#  4   geo          3200 non-null   str
#  5   country      3200 non-null   str
#  6   year         3200 non-null   int64
#  7   emissions    3200 non-null   float64
# dtypes: float64(1), int64(1), str(6)
# memory usage: 200.1 KB

# %%
df2["gas"].value_counts()
# Out:
# gas
# CO2    3200
# Name: count, dtype: int64

# %%
df2["sector"].value_counts()
# Out:
# sector
# CRF1          640
# CRF1A         640
# CRF1A1        640
# TOTX4_MEMO    640
# TOTXMEMO      640
# Name: count, dtype: int64

# %%
df2 = df2[df2["sector"] == "CRF1A1"].reset_index(drop=True)

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gas          640 non-null    str
#  1   gas_name     640 non-null    str
#  2   sector       640 non-null    str
#  3   sector_name  640 non-null    str
#  4   geo          640 non-null    str
#  5   country      640 non-null    str
#  6   year         640 non-null    int64
#  7   emissions    640 non-null    float64
# dtypes: float64(1), int64(1), str(6)
# memory usage: 40.1 KB

# %%
df2.to_csv("clean_eurostat_power_sector_emissions.csv", index=False)

# %%
#You now have a clean emissions dataset (640 records, 8 variables) that is ready for analysis.

📊 What the dataset contains
Each row represents emissions data for a specific gas, sector, country, and year.

🌍 Dimensions covered
Countries (geo + country name)

Years (time dimension)

Greenhouse gases (like CO2 and others)

Economic/industrial sectors (coded + named)

🧩 Structure of the data
Gas is recorded both as a code and a readable name

Sector is also duplicated as code + description

Countries are also stored as code + full name

Emissions are stored as a numeric value (float) → this is your key metric

📈 What this dataset lets you analyze
You can now easily study:

How emissions change over time (by year)

Which countries emit more or less

Which sectors contribute most to emissions

Which gases dominate total emissions (e.g. CO2 vs others)

Comparisons between industries and countries

🧠 Big picture
This dataset is basically a structured map of greenhouse gas emissions across Europe, broken down by:
👉 time
👉 geography
👉 sector
👉 gas type

So it's perfect for:

trend analysis

environmental impact comparisons

policy insights (which sectors/countries to target)
